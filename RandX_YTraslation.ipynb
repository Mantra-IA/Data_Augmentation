# %% [markdown]
# ### **Permisos de Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Importar librerias necesarias**

# %%
import os
import numpy as np
from PIL import Image
import tensorflow as tf
import random

# %% [markdown]
# ### **Aplicar el metodo RandXTraslation**

# %%
input_folder = '/content/drive/MyDrive/Data_Augmentation/0_Data_Gen_py/RESULTS/All_Mels_DIM_800/BI'
output_folder = '/content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/TraslA/BI'

# Asegúrate de que la carpeta de salida exista
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

def translate_image(image_array, translation_x):
    """
    Traslada una imagen en el eje X.

    Args:
    - image_array: Array de la imagen original (debe tener 3 canales RGB).
    - translation_x: Cantidad de píxeles para trasladar en el eje X.

    Returns:
    - Array de la imagen trasladada.
    """
    height, width, channels = image_array.shape

    # Crear una imagen de fondo con el mismo tamaño y 0s (negra)
    translated_image_array = np.zeros_like(image_array)

    # Calcular las posiciones de recorte y asignación
    if translation_x > 0:
        # Traslado a la derecha
        translated_image_array[:, translation_x:, :] = image_array[:, :-translation_x, :]
    elif translation_x < 0:
        # Traslado a la izquierda
        translated_image_array[:, :width + translation_x, :] = image_array[:, -translation_x:, :]

    return translated_image_array

# Itera sobre todas las imágenes en la carpeta de entrada
for image_name in os.listdir(input_folder):
    if image_name.endswith('.png'):
        input_image_path = os.path.join(input_folder, image_name)
        output_image_path = os.path.join(output_folder, image_name)

        # Carga la imagen
        image = Image.open(input_image_path).convert('RGB')  # Asegúrate de que la imagen esté en RGB
        image_array = np.array(image)

        # Determina aleatoriamente si trasladar hacia la izquierda o hacia la derecha
        translation_x = random.choice([-5, 5])

        # Traslada la imagen aleatoriamente 5 píxeles en el eje X
        translated_image_array = translate_image(image_array, translation_x)

        # Convierte el array de nuevo a imagen y guarda
        translated_image = Image.fromarray(translated_image_array)
        translated_image.save(output_image_path)

        print(f'Imagen trasladada guardada en: {output_image_path}')
# Out:
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/TraslA/BI/PPN_24_P2_89.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/TraslA/BI/PPN_48_P1_28.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/TraslA/BI/PPN_25_P4_89.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/TraslA/BI/PPN_24_P2_116.png
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     517     try:
# --> 518         fh = fp.fileno()
#     519         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-e5db875f95c8> in <cell line: 35>()
#      50         # Convierte el array de nuevo a imagen y guarda
#      51         translated_image = Image.fromarray(translated_image_array)
# ---> 52         translated_image.save(output_image_path)
#      53
#      54         print(f'Imagen trasladada guardada en: {output_image_path}')
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2429
#    2430         try:
# -> 2431             save_handler(self, fp, filename)
#    2432         except Exception:
#    2433             if open_fp:
#
# /usr/local/lib/python3.10/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1418         _write_multiple_frames(im, fp, chunk, rawmode, default_image, append_images)
#    1419     else:
# -> 1420         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1421
#    1422     if info:
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     520         _encode_tile(im, fp, tile, bufsize, fh)
#     521     except (AttributeError, io.UnsupportedOperation) as exc:
# --> 522         _encode_tile(im, fp, tile, bufsize, None, exc)
#     523     if hasattr(fp, "flush"):
#     524         fp.flush()
#
# /usr/local/lib/python3.10/dist-packages/PIL/ImageFile.py in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     540                     while True:
#     541                         l, s, d = encoder.encode(bufsize)
# --> 542                         fp.write(d)
#     543                         if s:
#     544                             break
#
# /usr/local/lib/python3.10/dist-packages/PIL/PngImagePlugin.py in write(self, data)
#    1095
#    1096     def write(self, data):
# -> 1097         self.chunk(self.fp, b"IDAT", data)
#    1098
#    1099
#
# /usr/local/lib/python3.10/dist-packages/PIL/PngImagePlugin.py in putchunk(fp, cid, *data)
#    1082
#    1083     fp.write(o32(len(data)) + cid)
# -> 1084     fp.write(data)
#    1085     crc = _crc32(data, _crc32(cid))
#    1086     fp.write(o32(crc))
#
# KeyboardInterrupt:

# %% [markdown]
# ### **Aplicar el metodo RandYTraslation**

# %%
output_folder = '/content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI'

# Asegúrate de que la carpeta de salida exista
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

def translate_image_y(image_array, translation_y):
    """
    Traslada una imagen en el eje Y.

    Args:
    - image_array: Array de la imagen original (debe tener 3 canales RGB).
    - translation_y: Cantidad de píxeles para trasladar en el eje Y.

    Returns:
    - Array de la imagen trasladada.
    """
    height, width, channels = image_array.shape

    # Crear una imagen de fondo con el mismo tamaño y 0s (negra)
    translated_image_array = np.zeros_like(image_array)

    # Calcular las posiciones de recorte y asignación
    if translation_y > 0:
        # Traslado hacia abajo
        translated_image_array[translation_y:, :, :] = image_array[:-translation_y, :, :]
    elif translation_y < 0:
        # Traslado hacia arriba
        translated_image_array[:height + translation_y, :, :] = image_array[-translation_y:, :, :]

    return translated_image_array

# Itera sobre todas las imágenes en la carpeta de entrada
for image_name in os.listdir(input_folder):
    if image_name.endswith('.png'):
        input_image_path = os.path.join(input_folder, image_name)
        output_image_path = os.path.join(output_folder, image_name)

        # Carga la imagen
        image = Image.open(input_image_path).convert('RGB')  # Asegúrate de que la imagen esté en RGB
        image_array = np.array(image)

        # Determina aleatoriamente si trasladar hacia arriba o hacia abajo
        translation_y = random.choice([-5, 5])

        # Traslada la imagen aleatoriamente 5 píxeles en el eje Y
        translated_image_array = translate_image_y(image_array, translation_y)

        # Convierte el array de nuevo a imagen y guarda
        translated_image = Image.fromarray(translated_image_array)
        translated_image.save(output_image_path)

        print(f'Imagen trasladada guardada en: {output_image_path}')
# Out:
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P2_89.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_48_P1_28.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_25_P4_89.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P2_116.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_34_P1_96.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P2_60.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P1_72.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P3_158.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P2_157.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P5_22.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P4_127.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P5_285.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P2_128.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_29_P5_281.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P1_169.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_43_P1_125.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_22_P4_130.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_27_P5_204.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_25_P1_260.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_22_P5_193.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P4_121.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_25_P3_73.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P2_250.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P5_207.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P4_129.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_P1_143.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_23_P4_63.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_25_P1_159.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_27_P1_216.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_34_P1_72.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_44_P4_236.png
# Imagen trasladada guardada en: /content/drive/MyDrive/Data_Augmentation/1_Data_Aug_py/RESULTS/RandYTraslation/BI/PPN_24_